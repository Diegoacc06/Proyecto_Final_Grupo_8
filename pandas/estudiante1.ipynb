# %%
pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 45.1 MB/s  0:00:006m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 47.3 MB/s  0:00:006m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]2m3/4 [pandas]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df=pd.read_csv("/workspaces/Proyecto_Final_Grupo_8/pandas/Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv")

# %%
def costo_promedio2(x):
    def crear_funcion_costo(num):
        polinomio= [23,2,num]
        c101=0
        c100=0
        exponente=0
        for k in polinomio:
            c101+=k*(101)**exponente
            c100+=k*(100)**exponente
            exponente+=1
        return (c101-c100)/(101-100)
    return crear_funcion_costo(x[4])

# %%
df["Valores Reales Punto 2"]=df.apply(costo_promedio2, axis=1 )
# Out:
# /tmp/ipykernel_36812/140529635.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return crear_funcion_costo(x[4])

# %%
df
# Out:
#     Número de documento  \
# 0            1021674384
# 1            1028481694
# 2            1012976628
# 3            1103500518
# 4            1141316451
# 5            1127228530
# 6            1000794960
# 7            1019606644
# 8            1104224296
# 9            1094049572
# 10           1025062924
# 11           1028485597
# 12           1013037578
# 13           1113364165
# 14           1140914656
# 15           1011095164
# 16           1193231792
# 17           1077228324
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                            7382.000
# 1                                            8817.000
# 2                                            8612.000
# 3                                            4922.000
# 4                                            5537.000
# 5                                            6357.000
# ...

# %%
def calificacion_P2(x):
    if x[1]==x[5]:
        return 5
    else:
        return 1

# %%
df["Nota Punto 2"]=df.apply(calificacion_P2, axis=1)
# Out:
# /tmp/ipykernel_36812/3492547345.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if x[1]==x[5]:

# %%
df
# Out:
#     Número de documento  \
# 0            1021674384
# 1            1028481694
# 2            1012976628
# 3            1103500518
# 4            1141316451
# 5            1127228530
# 6            1000794960
# 7            1019606644
# 8            1104224296
# 9            1094049572
# 10           1025062924
# 11           1028485597
# 12           1013037578
# 13           1113364165
# 14           1140914656
# 15           1011095164
# 16           1193231792
# 17           1077228324
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                            7382.000
# 1                                            8817.000
# 2                                            8612.000
# 3                                            4922.000
# 4                                            5537.000
# 5                                            6357.000
# ...

# %%
def costo_marginal(x):
    def crear_funcion_costo(num):
        polinomio= [2,2*num]
        c100=0
        exponente=0
        for k in polinomio:
            c100+=k*(100)**exponente
            exponente+=1
        return c100
    return crear_funcion_costo(x[4])

# %%
df["Valores Reales Punto 3"]= df.apply(costo_marginal, axis=1)
# Out:
# /tmp/ipykernel_36812/1330558048.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return crear_funcion_costo(x[4])

# %%
df
# Out:
#     Número de documento  \
# 0            1021674384
# 1            1028481694
# 2            1012976628
# 3            1103500518
# 4            1141316451
# 5            1127228530
# 6            1000794960
# 7            1019606644
# 8            1104224296
# 9            1094049572
# 10           1025062924
# 11           1028485597
# 12           1013037578
# 13           1113364165
# 14           1140914656
# 15           1011095164
# 16           1193231792
# 17           1077228324
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                            7382.000
# 1                                            8817.000
# 2                                            8612.000
# 3                                            4922.000
# 4                                            5537.000
# 5                                            6357.000
# ...

# %%
columna_object_idx = 3  # posición de la columna de tipo object

#Se procede a cambiar los valores con comas, por punto

df.iloc[:, columna_object_idx] = (
    df.iloc[:, columna_object_idx]
      .astype(str)
      .str.replace(",", ".", regex=False)
)

#Ahora se cambian todas las columnas a tipo numerico

df.iloc[:, columna_object_idx] = pd.to_numeric(df.iloc[:, columna_object_idx], errors="coerce")
# Out:
# /tmp/ipykernel_36812/1118410583.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0     7202.0
# 1     8602.0
# 2     8402.0
# 3     4802.0
# 4     5402.0
# 5     6202.0
# 6        2.0
# 7     7402.0
# 8       62.0
# 9     8202.0
# 10     6.202
# 11       2.0
# 12    7002.0
# 13    6202.0
# 14      76.0
# 15    5600.0
# 16       1.0
# 17    366.82
# Name: Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nUsar el costo marginal para aproximar el costo promedio entre x= 100 y x =101 (Poner dos decimales), dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, columna_object_idx] = (

# %%
def calificacion_P3(x):
    if x[3]==x[9]:
        return 5
    else:
        return 1

# %%
df["Nota Punto 3"]= df.apply(calificacion_P3, axis=1)
# Out:
# /tmp/ipykernel_36812/3925088704.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if x[3]==x[9]:

# %%
df
# Out:
#     Número de documento  \
# 0            1021674384
# 1            1028481694
# 2            1012976628
# 3            1103500518
# 4            1141316451
# 5            1127228530
# 6            1000794960
# 7            1019606644
# 8            1104224296
# 9            1094049572
# 10           1025062924
# 11           1028485597
# 12           1013037578
# 13           1113364165
# 14           1140914656
# 15           1011095164
# 16           1193231792
# 17           1077228324
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                            7382.000
# 1                                            8817.000
# 2                                            8612.000
# 3                                            4922.000
# 4                                            5537.000
# 5                                            6357.000
# ...

# %%
df.to_csv("Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv",index=False)
df
# Out:
#     Número de documento  \
# 0            1021674384
# 1            1028481694
# 2            1012976628
# 3            1103500518
# 4            1141316451
# 5            1127228530
# 6            1000794960
# 7            1019606644
# 8            1104224296
# 9            1094049572
# 10           1025062924
# 11           1028485597
# 12           1013037578
# 13           1113364165
# 14           1140914656
# 15           1011095164
# 16           1193231792
# 17           1077228324
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                            7382.000
# 1                                            8817.000
# 2                                            8612.000
# 3                                            4922.000
# 4                                            5537.000
# 5                                            6357.000
# ...

# %%
df= df.rename(columns={'Nota Punto 2':'CP2'})

# %%
df
# Out:
#     Número de documento  \
# 0            1021674384
# 1            1028481694
# 2            1012976628
# 3            1103500518
# 4            1141316451
# 5            1127228530
# 6            1000794960
# 7            1019606644
# 8            1104224296
# 9            1094049572
# 10           1025062924
# 11           1028485597
# 12           1013037578
# 13           1113364165
# 14           1140914656
# 15           1011095164
# 16           1193231792
# 17           1077228324
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                            7382.000
# 1                                            8817.000
# 2                                            8612.000
# 3                                            4922.000
# 4                                            5537.000
# 5                                            6357.000
# ...

# %%
df.to_csv("Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv",index=False)

# %%
df= df.rename(columns={'Nota Punto 3':'CP3'})

# %%
df
# Out:
#     Número de documento  \
# 0            1021674384
# 1            1028481694
# 2            1012976628
# 3            1103500518
# 4            1141316451
# 5            1127228530
# 6            1000794960
# 7            1019606644
# 8            1104224296
# 9            1094049572
# 10           1025062924
# 11           1028485597
# 12           1013037578
# 13           1113364165
# 14           1140914656
# 15           1011095164
# 16           1193231792
# 17           1077228324
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                            7382.000
# 1                                            8817.000
# 2                                            8612.000
# 3                                            4922.000
# 4                                            5537.000
# 5                                            6357.000
# ...

# %%
df.to_csv("Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv",index=False)

# %%
df=df.iloc[:,:-1]

# %%
df
# Out:
#     Número de documento  \
# 0            1021674384
# 1            1028481694
# 2            1012976628
# 3            1103500518
# 4            1141316451
# 5            1127228530
# 6            1000794960
# 7            1019606644
# 8            1104224296
# 9            1094049572
# 10           1025062924
# 11           1028485597
# 12           1013037578
# 13           1113364165
# 14           1140914656
# 15           1011095164
# 16           1193231792
# 17           1077228324
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                            7382.000
# 1                                            8817.000
# 2                                            8612.000
# 3                                            4922.000
# 4                                            5537.000
# 5                                            6357.000
# ...

# %%
df.to_csv("Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv",index=False)
